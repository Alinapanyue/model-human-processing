# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
from os import listdir
sns.set(style="ticks", font_scale=1.2)
plt.rc("axes.spines", top=False, right=False)

from utils import *

print("GPT-2 models in MODELS list:")
for m in MODELS:
    if 'gpt2' in m:
        print(f"  {m}: {get_model_size(m)}B")
# Out:
# OUTPUT measures (4): ['output_entropy', 'output_rank_correct', 'output_logprob_correct', 'output_logprobdiff']
# PROCESS measures (15): ['auc_entropy', 'layer_biggest_change_entropy', 'auc_rank_correct', 'layer_biggest_change_rank_correct', 'auc_logprob_correct', 'layer_biggest_change_logprob_correct', 'auc_logprobdiff_pos', 'auc_logprobdiff_neg', 'layer_biggest_change_logprobdiff', 'auc_boosting_pos', 'auc_boosting_neg', 'layer_argmax_boosting', 'twostage_magnitude', 'twostage_magnitude_latter34', 'twostage_layer']
# GPT-2 models in MODELS list:
#   gpt2: 0.124B
#   gpt2-medium: 0.355B
#   gpt2-large: 0.774B
#   gpt2-xl: 1.5B

# %% [markdown]
# # 1. Read and process model outputs

# %%
def expect_dual_processing(r):
    if r.task.startswith("capitals"):
        return r["condition"] == "has_competitor"
    elif r.task == "animals":
        return r["condition"] == "Atypical"
    elif r.task == "gender":
        return r["condition"] == "inconsistent"
    elif r.task == "syllogism":
        return (
            (r.is_realistic) and \
            ((r.is_consistent and not r.is_valid) or (not r.is_consistent and r.is_valid))
        )
    elif r.task == "colors":
        # Competitor condition: has intervening facts (creates conflict)
        return r["num_intervening_facts"] > 0
    else:
        raise ValueError(f"Unknown task: {r.task}")

def read_all_data(lens="logit_lens"):
    dfs = []
    for task in TASKS:
        print(task)
        try:
            df = pd.read_csv(f"../../data/model_output/processed/{task}_metrics_{lens}.csv")
        except FileNotFoundError:
            print(f"No data for {task} / {lens}; skipping")
            continue
        df["task"] = task
        df["model_family"] = df.model.apply(get_model_family)
        df["model_size"] = df.model.apply(get_model_size)
        df["log_model_size"] = np.log(df["model_size"])
        dfs.append(df)
    df = pd.concat(dfs).reset_index()
    df["expect_dual_processing"] = df.apply(expect_dual_processing, axis=1)
    print(df.groupby("task")["expect_dual_processing"].value_counts())
    df["expect_dual_processing_label"] = df.expect_dual_processing.map({
        True: "Competitor",
        False: "NoCompetitor"
    })
    return df

# Read data from all tasks.
df = read_all_data(lens="logit_lens")
print(df.model.unique())
df.head()
# Out:
# capitals-recall
# capitals-recognition
# animals
# gender
# syllogism
# colors
# task                  expect_dual_processing
# animals               False                      234
#                       True                       108
# capitals-recall       True                       756
#                       False                      360
# capitals-recognition  True                      1428
#                       False                      764
# colors                True                      6360
#                       False                      360
# gender                False                      720
#                       True                       720
# syllogism             False                     2448
#                       True                       816
# Name: count, dtype: int64
# ['Falcon3-10B-Base' 'Falcon3-1B-Base' 'Falcon3-3B-Base' 'Llama-2-13b-hf'
#  'Llama-2-70b-hf' 'Llama-2-7b-hf' 'Llama-3.1-405B' 'Llama-3.1-70B'
# ...

# %% [markdown]
# # 2. Figure 2a

# %%
def get_sig_code(p):
    if p < 0.001:
        return "***"
    elif p < 0.01:
        return "**"
    elif p < 0.05:
        return "*"
    elif p < 0.1:
        return "."
    else:
        return "n.s."

def plot_com_by_task(d, render=False, annot=True):
    hue_order = ["Competitor", "NoCompetitor"]
    metrics = ["twostage_magnitude", "twostage_layer"]
    ylabels = ["CoM", "TTD"]
    
    fig, axes = plt.subplots(nrows=2, ncols=1, sharex=True, sharey=False, figsize=(4.5,3))
    
    for i, ax in enumerate(axes):
        metric = metrics[i]
    
        sig_codes = []
        for task in TASKS:
            x1 = d[(d.task==task)&(d.expect_dual_processing)][metric]
            x2 = d[(d.task==task)&(~d.expect_dual_processing)][metric]
            t, p = stats.ttest_ind(x1, x2)
            print(f"t-test for {task}, {metric}: t={t}, p={p}")
            sig_codes.append(get_sig_code(p))

        ax = sns.barplot(
            data=d,
            x="task",
            order=TASKS,
            y=metric,
            hue="expect_dual_processing_label",
            hue_order=hue_order,
            palette=TWOSTAGE_PAL,
            err_kws={"lw": 1},
            ax=ax
        )
        if i == 0:
            ax.legend(
                title="", loc="lower center", bbox_to_anchor=(0.45,1), ncols=2, frameon=False,
                fontsize="small"
            )
        else:
            ax.get_legend().remove()
            ax.set_xticks(
                range(len(TASKS)),
                [TASK_NAMES[t].replace(" ", "\n") for t in TASKS],
                rotation=35,
                ha="right",
                size="small"
            )
        ax.set_xlabel("")
        ax.set_ylabel(ylabels[i])
        
        if annot:
            _, ymax = ax.get_ylim()
            for j, task in enumerate(TASKS):
                y = d[(d.task==task)&(d.expect_dual_processing)][metric].mean()
                sig_code = sig_codes[j]
                if i == 0:
                    y_delta = 0.5 if sig_code != "n.s." else 0.9
                else:
                    y_delta = 0.03
                
                if sig_code == ".":
                    kws = dict(size="medium", weight="bold")
                else:
                    kws = dict(size="small")
                ax.text(j, y+y_delta, sig_code, ha="center", **kws)
        
    fig.align_ylabels()
    plt.subplots_adjust(hspace=0.25)
    if render:
        plt.savefig("../../figures/twostage_means_by_task.pdf", dpi=300, bbox_inches="tight")
    plt.show()
    

plot_com_by_task(df, render=True)
# Out:
# t-test for capitals-recall, twostage_magnitude: t=10.281034220104239, p=9.498700969078036e-24
# t-test for capitals-recognition, twostage_magnitude: t=8.053489711271038, p=1.3074695559706776e-15
# t-test for animals, twostage_magnitude: t=1.823013462348652, p=0.06917938477310655
# t-test for gender, twostage_magnitude: t=0.25319440978325264, p=0.8001541771384768
# t-test for syllogism, twostage_magnitude: t=-0.626200039399831, p=0.5312275556426169
# t-test for colors, twostage_magnitude: t=0.6366871847679093, p=0.5243503157212934
# t-test for capitals-recall, twostage_layer: t=22.313567602287094, p=1.8241926921646533e-91
# t-test for capitals-recognition, twostage_layer: t=15.587335935001972, p=4.985699181534204e-52
# t-test for animals, twostage_layer: t=4.186101293966268, p=3.618274648390643e-05
# t-test for gender, twostage_layer: t=3.8942940826273422, p=0.0001030016036164806
# t-test for syllogism, twostage_layer: t=4.979552816091434, p=6.703998668151344e-07
# ...

# %%
def get_bucket_label(b):
    lo, hi = b.split(", ")
    lo = float(lo.lstrip("("))
    hi = float(hi.rstrip("]"))
    if str(lo).endswith(".0"):
        lo_str = str(int(lo))
    else:
        lo_str = str(lo)
    if str(hi).endswith(".0"):
        hi_str = str(int(hi))
    else:
        hi_str = str(hi)
    return f"({lo_str}, {hi_str}]"
        
def plot_com_by_size(data, n_buckets=4, render=False):
    # Filter out rows with NaN model_size
    data = data[data["model_size"].notna()].copy()
    
    # Add model size "bucket".
    buckets = pd.qcut(data["model_size"], n_buckets)
    data["model_size_bucket"] = buckets
    order = sorted(data["model_size_bucket"].unique())
    
    metrics = ["twostage_magnitude", "twostage_layer"]
    ylabels = ["CoM", "TTD"]
    
    fig, axes = plt.subplots(nrows=2, ncols=1, sharex=True, sharey=False, figsize=(2.5,3))
    for i, ax in enumerate(axes):
        metric = metrics[i]
        ax = sns.pointplot(
            data=data,
            x="model_size_bucket",
            order=order,
            y=metric,
            hue="expect_dual_processing_label",
            palette=TWOSTAGE_PAL,
            err_kws=dict(lw=1),
            alpha=1,
            markers=["o", "v"],
            linestyles=["-", "--"],
            ax=ax
        )
        if i == 0:
            ax.legend(
                title="", loc="lower center", bbox_to_anchor=(0.4,1.1), ncol=2,frameon=False,
                columnspacing=1, handletextpad=0.4, fontsize="small"
            )
        else:
            ax.get_legend().remove()
            labs = ax.get_xticklabels()
            pretty_labs = [get_bucket_label(lab.get_text()) for lab in labs]
            ax.set_xticks(
                range(len(labs)),
                pretty_labs,
                rotation=35,
                ha="right",
                size="small"
            )
            ax.set_xlabel("Billions of parameters")
        ax.set_ylabel(ylabels[i])
    fig.align_ylabels()
    plt.subplots_adjust(hspace=0.25)
    if render:
        plt.savefig("../../figures/twostage_by_size.pdf", dpi=300, bbox_inches="tight")
    plt.show()
        
plot_com_by_size(df, n_buckets=5, render=True)

# %%
def read_layerwise_data(task, data_dir="../../data/model_output/logit_lens"):
    C_VAR = "correct"
    I_VAR = "incorrect"
    print(f"Reading model data for the following task: {task}")
    dfs = []
    files = sorted([f for f in listdir(data_dir) if f.startswith(task)])
    for file in files:
        model = file.split("_")[-1].strip(".csv")
        if model not in N_LAYERS.keys():
            print(f"Skipping model {model}")
            continue
        df = pd.read_csv(f"{data_dir}/{file}")
        assert df.layer_idx.nunique() == N_LAYERS[model]
        # Add column for whether the layer is the final layer.
        # This is model-dependent.
        max_layer = df["layer_idx"].max()
        df["is_final_layer"] = df["layer_idx"] == max_layer
        # Add normalized layer (between 0-1).
        df["layer_01"] = df["layer_idx"] / max_layer
        df["model"] = model
        dfs.append(df)
    df = pd.concat(dfs).reset_index().drop(columns=["index"])
    # Add columns for logprob diffs.
    for metric in ["sum", "mean", "first"]:
        df[f"{metric}_logprob_diff"] = df[f"{metric}_logprob_{C_VAR}"] - df[f"{metric}_logprob_{I_VAR}"]
    return df

def plot_logprobdiffs(df, models):
    metric_name = "first_logprob_diff"
    palette = ["#E39B38FF", "#B6BDCCFF", "#9B593FFF"]
    conditions = ["has_competitor", "no_competitor"]
    names = ["Competitor", "NoCompetitor"]
    fig, axes = plt.subplots(nrows=1, ncols=2, sharex=True, sharey=True)
    for i, ax in enumerate(axes):
        condition = conditions[i]
        ax = sns.lineplot(
            data=df[df.condition==condition],
            x="layer_01",
            y=metric_name, 
            lw=2.5,
            hue="model",
            hue_order=models,
            palette=palette,
            ax=ax
        )
        ax.set_xlabel("")
        if i==0:
            ax.set_ylabel("$\\Delta$ Logprob")
        else:
            ax.set_ylabel("")
        ax.get_legend().remove()
        ax.axhline(y=0, linestyle="--", color="k", alpha=0.5, zorder=-2)
        ax.set_title(names[i], y=1.05)
        
    handles, labels = ax.get_legend_handles_labels()
    labels = [MODEL_MAP[m] for m in labels]
    plt.figlegend(
        handles, labels, title="", loc="upper center", bbox_to_anchor=(0.5, -0.2), 
        ncol=1, frameon=False)
    fig.supxlabel("Layer (normalized)", size="medium", y=-0.15)
    plt.gcf().set_size_inches(4,2)
    
layer_df = read_layerwise_data("capitals-recall")
models = ["gpt2", "OLMo-2-1124-13B", "Llama-3.1-405B"]
plot_logprobdiffs(
    layer_df[(layer_df.model.isin(models))], 
    models
)
plt.savefig(f"../../figures/twostage_layers_capitals-recall.pdf", dpi=300, bbox_inches="tight")
# Out:
# Reading model data for the following task: capitals-recall

# %% [markdown]
# # Appendix

# %%
def get_within_family_label(m):
    size = get_model_size(m)
    if size < 1:
        return str(int(size*1000)) + "M"
    else:
        return str(size) + "B"

def plot_dual_processing_metric(d, metric="twostage"):
    order = [
        "Competitor",
        "NoCompetitor"
    ]
    if metric == "twostage_magnitude":
        ylabel = "CoM"
    else:
        ylabel = "TTD"
    fig, axes = plt.subplots(nrows=1, ncols=len(MODEL_FAMILIES), figsize=(14,2))
    for i, (ax, family) in enumerate(zip(axes, MODEL_FAMILIES)):
        models = [m for m in MODELS if get_model_family(m) == family]
        ax = sns.pointplot(
            data=d[d.model_family==family],
            x="model",
            order=models,
            y=metric,
            hue="expect_dual_processing_label",
            hue_order=order,
            palette=TWOSTAGE_PAL,
            ax=ax,
            markers=['o', 'v'],
            linestyles=["-", "--"],
            err_kws=dict(lw=1.5)
        )
        ax.set_title(family)
        ax.set_xlabel("")
        ax.set_xticks(
            range(len(models)), 
            [get_within_family_label(m) for m in models],
        )
        if i == 0:
            ax.set_ylabel(ylabel)
        else:
            ax.set_ylabel("")
        ax.get_legend().remove()
        yticklabs = ax.get_yticklabels()
        ax.set_yticklabels(yticklabs, size="small")

    handles, labels = ax.get_legend_handles_labels()
    fig.supxlabel("Model size", y=-0.2, size="medium")
    plt.figlegend(handles, labels, loc="upper center", bbox_to_anchor=(0.5,-0.2), frameon=False, ncol=2, title="")

for metric in ["twostage_magnitude", "twostage_layer"]:
    plot_dual_processing_metric(
        df,
        metric=metric
    )
    plt.savefig(f"../../figures/{metric}_by_model.pdf", dpi=300, bbox_inches="tight")
    plt.show()
# Out:
# /var/folders/0n/8r8bnjds7lgcqhkskq0z8f9r0000gn/T/ipykernel_52465/2200234465.py:45: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(yticklabs, size="small")
# /var/folders/0n/8r8bnjds7lgcqhkskq0z8f9r0000gn/T/ipykernel_52465/2200234465.py:45: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(yticklabs, size="small")
# /var/folders/0n/8r8bnjds7lgcqhkskq0z8f9r0000gn/T/ipykernel_52465/2200234465.py:45: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(yticklabs, size="small")
# /var/folders/0n/8r8bnjds7lgcqhkskq0z8f9r0000gn/T/ipykernel_52465/2200234465.py:45: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(yticklabs, size="small")
# /var/folders/0n/8r8bnjds7lgcqhkskq0z8f9r0000gn/T/ipykernel_52465/2200234465.py:45: UserWarning: FixedFormatter should only be used together with FixedLocator
# ...

# %%
# Filter for colors task only
colors_df = df[df.task == "colors"].copy()

def plot_colors_gpt2_metric(d, metric="twostage_magnitude"):
    """Plot only GPT-2 family for colors task"""
    order = [
        "Competitor",
        "NoCompetitor"
    ]
    if metric == "twostage_magnitude":
        ylabel = "CoM"
    else:
        ylabel = "TTD"
    
    # Only GPT-2 models
    gpt2_models = ["gpt2", "gpt2-medium", "gpt2-large", "gpt2-xl"]
    
    # Single subplot for GPT-2 family
    fig, ax = plt.subplots(figsize=(4, 3))
    
    ax = sns.pointplot(
        data=d[d.model_family=="GPT-2"],
        x="model",
        order=gpt2_models,
        y=metric,
        hue="expect_dual_processing_label",
        hue_order=order,
        palette=TWOSTAGE_PAL,
        ax=ax,
        markers=['o', 'v'],
        linestyles=["-", "--"],
        err_kws=dict(lw=1.5)
    )
    
    ax.set_title("GPT-2 (Colors Task)")
    ax.set_xlabel("Model size")
    ax.set_xticks(
        range(len(gpt2_models)), 
        [get_within_family_label(m) for m in gpt2_models],
    )
    ax.set_ylabel(ylabel)
    
    handles, labels = ax.get_legend_handles_labels()
    ax.legend(
        handles, labels, 
        loc="best", 
        frameon=False, 
        title=""
    )
    
    plt.tight_layout()
    return fig

# Plot both metrics for colors task (GPT-2 only)
for metric in ["twostage_magnitude", "twostage_layer"]:
    fig = plot_colors_gpt2_metric(colors_df, metric=metric)
    plt.savefig(f"../../figures/colors_{metric}_gpt2_only.pdf", dpi=300, bbox_inches="tight")
    plt.show()

# %%
# ============================================================
# EXPERIMENT 1 ANALYSIS: Dose-Response of Fact Number & Type
# ============================================================

# Filter for experiment_1 data only
exp1_df = df[(df.task == "colors") & (df.experiment == "experiment_1")].copy()

print(f"Experiment 1 data: {len(exp1_df)} rows")
print(f"Models: {exp1_df.model.unique()}")
print(f"Conditions: {sorted(exp1_df.fact_type_condition.unique())}")

# Add fact number and fact style as separate columns for easier analysis
def parse_exp1_condition(cond):
    """Parse experiment_1 conditions into number and style"""
    if cond == "baseline":
        return 0, "none"
    elif cond.startswith("normal_"):
        num = int(cond.split("_")[1])
        return num, "normal"
    elif cond.startswith("strange_"):
        num = int(cond.split("_")[1])
        return num, "strange"
    else:
        return None, None

exp1_df["fact_number"] = exp1_df.fact_type_condition.apply(lambda x: parse_exp1_condition(x)[0])
exp1_df["fact_style"] = exp1_df.fact_type_condition.apply(lambda x: parse_exp1_condition(x)[1])

# Plot 1: CoM vs Number of Facts (Normal vs Strange)
# Changed to 2 rows, 1 column for better readability
fig, axes = plt.subplots(2, 1, figsize=(10, 10))

for i, model_family in enumerate(["GPT-2", "Llama-2"]):
    data = exp1_df[
        (exp1_df.model_family == model_family) & 
        (exp1_df.fact_number > 0)  # Exclude baseline
    ]
    
    sns.lineplot(
        data=data,
        x="fact_number",
        y="twostage_magnitude",
        hue="fact_style",
        hue_order=["normal", "strange"],
        style="model",
        markers=True,
        markersize=8,
        linewidth=2.5,
        ax=axes[i]
    )
    
    axes[i].set_title(f"{model_family} Family", fontsize=14, fontweight='bold')
    axes[i].set_xlabel("Number of Intervening Facts", fontsize=12)
    axes[i].set_ylabel("CoM (Change of Mind)", fontsize=12)
    axes[i].legend(title="Fact Type", loc="best", fontsize=10)
    axes[i].grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig("../../figures/exp1_com_by_fact_number.pdf", dpi=300, bbox_inches="tight")
plt.show()

# Plot 2: TTD vs Number of Facts
# Changed to 2 rows, 1 column for better readability
fig, axes = plt.subplots(2, 1, figsize=(10, 10))

for i, model_family in enumerate(["GPT-2", "Llama-2"]):
    data = exp1_df[
        (exp1_df.model_family == model_family) & 
        (exp1_df.fact_number > 0)
    ]
    
    sns.lineplot(
        data=data,
        x="fact_number",
        y="twostage_layer",
        hue="fact_style",
        hue_order=["normal", "strange"],
        style="model",
        markers=True,
        markersize=8,
        linewidth=2.5,
        ax=axes[i]
    )
    
    axes[i].set_title(f"{model_family} Family", fontsize=14, fontweight='bold')
    axes[i].set_xlabel("Number of Intervening Facts", fontsize=12)
    axes[i].set_ylabel("TTD (Time to Decision)", fontsize=12)
    axes[i].legend(title="Fact Type", loc="best", fontsize=10)
    axes[i].grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig("../../figures/exp1_ttd_by_fact_number.pdf", dpi=300, bbox_inches="tight")
plt.show()

# Summary statistics
print("\n=== Experiment 1 Summary Statistics ===")
summary = exp1_df[exp1_df.fact_number > 0].groupby(["fact_number", "fact_style"])[
    ["twostage_magnitude", "twostage_layer"]
].agg(["mean", "std"])
print(summary)
# Out:
# Experiment 1 data: 2640 rows
# Models: ['Llama-2-13b-hf' 'Llama-2-7b-hf' 'Llama-3.2-1B' 'Llama-3.2-3B'
#  'gpt2-large' 'gpt2-medium' 'gpt2-xl' 'gpt2']
# Conditions: ['baseline', 'normal_1', 'normal_2', 'normal_3', 'normal_4', 'normal_5', 'strange_1', 'strange_2', 'strange_3', 'strange_4', 'strange_5']
# === Experiment 1 Summary Statistics ===
#                        twostage_magnitude           twostage_layer
#                                      mean       std           mean       std
# fact_number fact_style
# 1           normal               1.666804  1.348816       0.577570  0.310492
#             strange              1.668829  1.354699       0.562948  0.308058
# 2           normal               1.680964  1.342557       0.574951  0.315884
#             strange              1.682237  1.369666       0.566779  0.311274
# 3           normal               1.674619  1.318474       0.571662  0.321114
#             strange              1.660000  1.357463       0.564774  0.317640
# ...

# %%
baseline = exp1_df[exp1_df.fact_number == 0]["twostage_magnitude"].mean()
print(f"Baseline CoM (0 facts): {baseline:.3f}")
print(f"1 fact CoM: 1.67")
print(f"Difference: {1.67 - baseline:.3f}")

high_com = exp1_df[exp1_df.twostage_magnitude > 1.0]
low_com = exp1_df[exp1_df.twostage_magnitude <= 1.0]
print(f"High CoM items (>1.0): {len(high_com)} ({len(high_com)/len(exp1_df)*100:.1f}%)")
print(f"Low CoM items (≤1.0): {len(low_com)} ({len(low_com)/len(exp1_df)*100:.1f}%)")

for model in exp1_df.model.unique():
    model_data = exp1_df[exp1_df.model == model]
    print(f"\n{model}:")
    print(model_data.groupby("fact_number")["twostage_magnitude"].mean())
# Out:
# Baseline CoM (0 facts): 1.611
# 1 fact CoM: 1.67
# Difference: 0.059
# High CoM items (>1.0): 1632 (61.8%)
# Low CoM items (≤1.0): 1008 (38.2%)
#
# Llama-2-13b-hf:
# fact_number
# 0    1.696767
# 1    1.754233
# 2    1.783033
# 3    1.873983
# 4    1.911467
# 5    1.989967
# Name: twostage_magnitude, dtype: float64
#
# Llama-2-7b-hf:
# fact_number
# 0    2.729867
# 1    2.808717
# 2    2.825017
# 3    2.723583
# 4    2.702650
# 5    2.558883
# Name: twostage_magnitude, dtype: float64
#
# Llama-3.2-1B:
# fact_number
# 0    2.519200
# 1    2.710533
# 2    2.775850
# 3    2.792550
# 4    2.727467
# 5    2.778250
# Name: twostage_magnitude, dtype: float64
#
# Llama-3.2-3B:
# fact_number
# 0    1.919033
# 1    1.888933
# 2    1.949450
# 3    2.037933
# 4    2.045367
# 5    2.083817
# Name: twostage_magnitude, dtype: float64
#
# gpt2-large:
# fact_number
# 0    0.231733
# 1    0.271950
# 2    0.261100
# 3    0.274667
# 4    0.217450
# 5    0.186850
# ...

# %%
# ============================================================
# EXPERIMENT 2 ANALYSIS: Model Family Comparison
# ============================================================

# Use same experiment_1 data but focus on cross-family comparison
exp2_df = exp1_df.copy()

# Define model pairs for comparison
model_pairs = [
    ("gpt2", "Llama-3.2-1B"),
    ("gpt2-medium", "Llama-3.2-3B"),
    ("gpt2-large", "Llama-2-7b-hf"),
    ("gpt2-xl", "Llama-2-13b-hf")
]

# Plot: Compare CoM across model pairs at different fact numbers
# Changed to 4 rows, 1 column for better readability
fig, axes = plt.subplots(4, 1, figsize=(12, 20))

for idx, (gpt_model, llama_model) in enumerate(model_pairs):
    data = exp2_df[
        (exp2_df.model.isin([gpt_model, llama_model])) &
        (exp2_df.fact_number > 0)
    ]
    
    sns.lineplot(
        data=data,
        x="fact_number",
        y="twostage_magnitude",
        hue="model",
        style="fact_style",
        markers=True,
        markersize=8,
        linewidth=2.5,
        ax=axes[idx]
    )
    
    gpt_size = get_model_size(gpt_model)
    llama_size = get_model_size(llama_model)
    axes[idx].set_title(f"GPT-2 ({gpt_size}B) vs Llama ({llama_size}B)", 
                        fontsize=14, fontweight='bold')
    axes[idx].set_xlabel("Number of Facts", fontsize=12)
    axes[idx].set_ylabel("CoM", fontsize=12)
    axes[idx].legend(title="Model | Fact Type", fontsize=10, loc="best")
    axes[idx].grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig("../../figures/exp2_model_family_comparison.pdf", dpi=300, bbox_inches="tight")
plt.show()

# Test gpt2-large anomaly in Llama-2-7b
print("\n=== Experiment 2: Testing gpt2-large Anomaly ===")
anomaly_data = exp2_df[
    (exp2_df.model.isin(["gpt2-large", "Llama-2-7b-hf"])) &
    (exp2_df.fact_number == 5) &
    (exp2_df.fact_style == "normal")
]

print("\nCoM for 5 normal facts:")
print(anomaly_data.groupby("model")["twostage_magnitude"].agg(["mean", "std", "count"]))

print("\nTTD for 5 normal facts:")
print(anomaly_data.groupby("model")["twostage_layer"].agg(["mean", "std", "count"]))
# Out:
# === Experiment 2: Testing gpt2-large Anomaly ===
#
# CoM for 5 normal facts:
#                  mean       std  count
# model
# Llama-2-7b-hf  2.5145  1.336830     30
# gpt2-large     0.2030  0.315197     30
#
# TTD for 5 normal facts:
#                    mean       std  count
# model
# Llama-2-7b-hf  0.544792  0.279952     30
# gpt2-large     0.352778  0.389514     30

# %%
# ============================================================
# EXPERIMENT 3 ANALYSIS: Individual Fact Type Effects
# ============================================================

exp3_df = df[(df.task == "colors") & (df.experiment == "experiment_3")].copy()

print(f"Experiment 3 data: {len(exp3_df)} rows")
print(f"Models: {exp3_df.model.unique()}")

# Parse fact type and style
def parse_exp3_condition(cond):
    parts = cond.rsplit("_", 1)
    return (parts[0], parts[1]) if len(parts) == 2 else (None, None)

exp3_df["fact_category"] = exp3_df.fact_type_condition.apply(lambda x: parse_exp3_condition(x)[0])
exp3_df["fact_style"] = exp3_df.fact_type_condition.apply(lambda x: parse_exp3_condition(x)[1])

fact_order = ["appearance", "type", "subtype", "place", "size"]

# Plot 1: Side-by-side comparison with SAME y-axis scale
fig, axes = plt.subplots(1, 2, figsize=(12, 5), sharey=True)  # 添加 sharey=True

for i, style in enumerate(["normal", "strange"]):
    data = exp3_df[exp3_df.fact_style == style]
    
    sns.barplot(
        data=data,
        x="fact_category",
        y="twostage_magnitude",
        order=fact_order,
        ax=axes[i],
        errorbar="se",
        capsize=0.1  # 添加 error bar caps
    )
    
    axes[i].set_title(f"{style.capitalize()} Facts", fontsize=12)
    axes[i].set_xlabel("Fact Type")
    axes[i].set_ylabel("CoM (Change of Mind)" if i == 0 else "")
    axes[i].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.savefig("../../figures/exp3_fact_type_ranking.pdf", dpi=300, bbox_inches="tight")
plt.show()

# Plot 2: Direct comparison with difference highlighted
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Left: Bar plot comparison
sns.barplot(
    data=exp3_df,
    x="fact_category",
    y="twostage_magnitude",
    hue="fact_style",
    hue_order=["normal", "strange"],
    order=fact_order,
    ax=axes[0],
    errorbar="se",
    capsize=0.1
)
axes[0].set_xlabel("Fact Type")
axes[0].set_ylabel("CoM (Change of Mind)")
axes[0].set_title("Normal vs Strange Facts by Type")
axes[0].legend(title="Fact Style")
axes[0].tick_params(axis='x', rotation=45)

# Right: Difference plot (Normal - Strange)
summary = exp3_df.groupby(["fact_category", "fact_style"])["twostage_magnitude"].agg(['mean', 'sem']).unstack()
diff = summary['mean']['normal'] - summary['mean']['strange']
diff_sem = np.sqrt(summary['sem']['normal']**2 + summary['sem']['strange']**2)

axes[1].bar(range(len(fact_order)), 
            [diff.get(f, 0) for f in fact_order],
            yerr=[diff_sem.get(f, 0) for f in fact_order],
            capsize=5,
            color=['red' if d < 0 else 'blue' for d in [diff.get(f, 0) for f in fact_order]])
axes[1].axhline(0, color='black', linestyle='--', linewidth=0.8)
axes[1].set_xticks(range(len(fact_order)))
axes[1].set_xticklabels(fact_order, rotation=45)
axes[1].set_xlabel("Fact Type")
axes[1].set_ylabel("Δ CoM (Normal - Strange)")
axes[1].set_title("Effect Size: Normal - Strange")

plt.tight_layout()
plt.savefig("../../figures/exp3_normal_vs_strange_by_type.pdf", dpi=300, bbox_inches="tight")
plt.show()

# Summary statistics
print("\n=== Experiment 3: Fact Type Ranking ===")
ranking = exp3_df.groupby(["fact_category", "fact_style"])["twostage_magnitude"].mean().unstack()
ranking["difference"] = ranking["normal"] - ranking["strange"]
ranking = ranking.sort_values("normal", ascending=False)

print("\nRanking by CoM (higher = more interference):")
print(ranking.round(3))

# Statistical test for each fact type
from scipy import stats
print("\n=== Statistical Tests (Normal vs Strange) ===")
for fact in fact_order:
    normal_data = exp3_df[(exp3_df.fact_category == fact) & 
                          (exp3_df.fact_style == "normal")]["twostage_magnitude"]
    strange_data = exp3_df[(exp3_df.fact_category == fact) & 
                           (exp3_df.fact_style == "strange")]["twostage_magnitude"]
    
    if len(normal_data) > 0 and len(strange_data) > 0:
        t_stat, p_val = stats.ttest_ind(normal_data, strange_data)
        sig = "***" if p_val < 0.001 else "**" if p_val < 0.01 else "*" if p_val < 0.05 else "ns"
        print(f"{fact:12s}: t={t_stat:6.2f}, p={p_val:.4f} {sig}")
# Out:
# Experiment 3 data: 2400 rows
# Models: ['Llama-2-13b-hf' 'Llama-2-7b-hf' 'Llama-3.2-1B' 'Llama-3.2-3B'
#  'gpt2-large' 'gpt2-medium' 'gpt2-xl' 'gpt2']
# === Experiment 3: Fact Type Ranking ===
#
# Ranking by CoM (higher = more interference):
# fact_style     normal  strange  difference
# fact_category
# subtype         1.699    1.662       0.036
# type            1.682    1.668       0.014
# size            1.679    1.668       0.011
# place           1.673    1.669       0.004
# appearance      1.667    1.669      -0.002
#
# === Statistical Tests (Normal vs Strange) ===
# appearance  : t= -0.02, p=0.9869 ns
# type        : t=  0.12, p=0.9073 ns
# subtype     : t=  0.29, p=0.7687 ns
# place       : t=  0.03, p=0.9764 ns
# size        : t=  0.09, p=0.9314 ns
